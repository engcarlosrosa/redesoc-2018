# %% [markdown]
# # Lacunas Estruturais
#
# Importando bibliotecas:

# %%
import pandas as pd
import networkx as nx
import socnet as sn

from random import shuffle
from itertools import combinations
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# Configurando bibliotecas:

# %%
sn.node_size = 5

sn.edge_width = 1
sn.edge_color = (191, 191, 191)

# %% [markdown]
# Definindo constantes:

# %%
FRAC_CLOSERS = 0.40

NUM_NODES = 25

DENSITY = 0.5

OPENER = 0 #busca lacuna estrutural
CLOSER = 1 #não quer lacuna estrutural

OPENER_COLOR = (255, 0, 0)
CLOSER_COLOR = (0, 0, 255)

# %% [markdown]
# Exemplo de grafo:
#
# (esse grafo representa o *ambiente* do modelo)

# %%
def build_graph():
    g = nx.erdos_renyi_graph(NUM_NODES, DENSITY)
    #gera grafos aleatórios, 
    #que inclui o limite entre cada par de nós com igual probabilidade, 
    #independentemente das extremidades

    sn.reset_node_colors(g)
    sn.reset_edge_colors(g)

    return g


g = build_graph()

sn.reset_positions(g)

sn.show_graph(g)
# Out:
# <div id="0125d5df-7da6-4a4f-8f6b-f891414fc6a4" style="height: 450px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0125d5df-7da6-4a4f-8f6b-f891414fc6a4", [{"hoverinfo": "none", "line": {"color": "rgb(191, 191, 191)", "width": 1}, "mode": "lines", "x": [0.18485703777741588, 0.5230232665878404, null, 0.18485703777741588, 0.608905898657026, null, 0.18485703777741588, 0.4550479772583669, null, 0.18485703777741588, 0.41186983516815334, null, 0.18485703777741588, 0.40611815720164385, null, 0.18485703777741588, 0.10628246242596973, null, 0.18485703777741588, 0.26808042673921223, null, 0.18485703777741588, 0.5467145114111778, null, 0.18485703777741588, 0.3290079309350088, null, 0.18485703777741588, 0.0, null, 0.18485703777741588, 0.80129889598982, null, 0.8498830984995434, 0.5364539776964787, null, 0.8498830984995434, 1.0, null, 0.8498830984995434, 0.608905898657026, null, 0.8498830984995434, 0.2205595953266284, null, 0.8498830984995434, 0.9196732654298817, null, 0.8498830984995434, 0.9240591530786384, null, 0.8498830984995434, 0.40611815720164385, null, 0.8498830984995434, 0.5835924420624169, null, 0.8498830984995434, 0.6425545033947377, null, 0.8498830984995434, 0.6625339828929624, null, 0.8498830984995434, 0.7974008759015665, null, 0.8498830984995434, 0.80129889598982, null, 0.5230232665878404, 0.5364539776964787, null, 0.5230232665878404, 0.608905898657026, null, 0.5230232665878404, 0.2205595953266284, null, 0.5230232665878404, 0.9240591530786384, null, 0.5230232665878404, 0.40611815720164385, null, 0.5230232665878404, 0.10628246242596973, null, 0.5230232665878404, 0.4526939577202225, null, 0.5230232665878404, 0.6425545033947377, null, 0.5230232665878404, 0.5467145114111778, null, 0.5230232665878404, 0.7974008759015665, null, 0.5230232665878404, 0.3473443627462505, null, 0.5230232665878404, 0.80129889598982, null, 0.5364539776964787, 0.2205595953266284, null, 0.5364539776964787, 0.26808042673921223, null, 0.5364539776964787, 0.5467145114111778, null, 0.5364539776964787, 0.3290079309350088, null, 0.5364539776964787, 0.7974008759015665, null, 0.5364539776964787, 0.80129889598982, null, 1.0, 0.41186983516815334, null, 1.0, 0.9196732654298817, null, 1.0, 0.9240591530786384, null, 1.0, 0.5835924420624169, null, 1.0, 0.4526939577202225, null, 1.0, 0.3290079309350088, null, 1.0, 0.80129889598982, null, 0.608905898657026, 0.41186983516815334, null, 0.608905898657026, 0.2205595953266284, null, 0.608905898657026, 0.9196732654298817, null, 0.608905898657026, 0.9240591530786384, null, 0.608905898657026, 0.40611815720164385, null, 0.608905898657026, 0.5835924420624169, null, 0.608905898657026, 0.26808042673921223, null, 0.608905898657026, 0.6425545033947377, null, 0.608905898657026, 0.3473443627462505, null, 0.4550479772583669, 0.9196732654298817, null, 0.4550479772583669, 0.9240591530786384, null, 0.4550479772583669, 0.26808042673921223, null, 0.4550479772583669, 0.4526939577202225, null, 0.4550479772583669, 0.6425545033947377, null, 0.4550479772583669, 0.0, null, 0.4550479772583669, 0.6519657060978772, null, 0.4550479772583669, 0.3473443627462505, null, 0.4550479772583669, 0.80129889598982, null, 0.41186983516815334, 0.2205595953266284, null, 0.41186983516815334, 0.9196732654298817, null, 0.41186983516815334, 0.5835924420624169, null, 0.41186983516815334, 0.26808042673921223, null, 0.41186983516815334, 0.0, null, 0.41186983516815334, 0.3473443627462505, null, 0.2205595953266284, 0.40611815720164385, null, 0.2205595953266284, 0.26808042673921223, null, 0.2205595953266284, 0.4526939577202225, null, 0.2205595953266284, 0.6425545033947377, null, 0.2205595953266284, 0.3290079309350088, null, 0.9196732654298817, 0.6425545033947377, null, 0.9196732654298817, 0.5467145114111778, null, 0.9196732654298817, 0.6625339828929624, null, 0.9196732654298817, 0.6519657060978772, null, 0.91967 ...

# %% [markdown]
# Exemplo de distribuição de tipos de nó:
#
# (esses tipos representam os *agentes* do modelo)

# %%
def set_types(g, num_closers=0):
    nodes = list(g.nodes)
    shuffle(nodes)

    for n in nodes[num_closers:]:
        g.nodes[n]['type'] = OPENER

    for n in nodes[:num_closers]:
        g.nodes[n]['type'] = CLOSER

    for n in g.nodes:
        if g.nodes[n]['type'] == OPENER:
            g.nodes[n]['color'] = OPENER_COLOR
        else:
            g.nodes[n]['color'] = CLOSER_COLOR


set_types(g, int(NUM_NODES / 2))

sn.show_graph(g)
# Out:
# <div id="ffa34cc1-c63a-4c9f-82eb-1f93844fa5f1" style="height: 450px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ffa34cc1-c63a-4c9f-82eb-1f93844fa5f1", [{"hoverinfo": "none", "line": {"color": "rgb(191, 191, 191)", "width": 1}, "mode": "lines", "x": [0.18485703777741588, 0.5230232665878404, null, 0.18485703777741588, 0.608905898657026, null, 0.18485703777741588, 0.4550479772583669, null, 0.18485703777741588, 0.41186983516815334, null, 0.18485703777741588, 0.40611815720164385, null, 0.18485703777741588, 0.10628246242596973, null, 0.18485703777741588, 0.26808042673921223, null, 0.18485703777741588, 0.5467145114111778, null, 0.18485703777741588, 0.3290079309350088, null, 0.18485703777741588, 0.0, null, 0.18485703777741588, 0.80129889598982, null, 0.8498830984995434, 0.5364539776964787, null, 0.8498830984995434, 1.0, null, 0.8498830984995434, 0.608905898657026, null, 0.8498830984995434, 0.2205595953266284, null, 0.8498830984995434, 0.9196732654298817, null, 0.8498830984995434, 0.9240591530786384, null, 0.8498830984995434, 0.40611815720164385, null, 0.8498830984995434, 0.5835924420624169, null, 0.8498830984995434, 0.6425545033947377, null, 0.8498830984995434, 0.6625339828929624, null, 0.8498830984995434, 0.7974008759015665, null, 0.8498830984995434, 0.80129889598982, null, 0.5230232665878404, 0.5364539776964787, null, 0.5230232665878404, 0.608905898657026, null, 0.5230232665878404, 0.2205595953266284, null, 0.5230232665878404, 0.9240591530786384, null, 0.5230232665878404, 0.40611815720164385, null, 0.5230232665878404, 0.10628246242596973, null, 0.5230232665878404, 0.4526939577202225, null, 0.5230232665878404, 0.6425545033947377, null, 0.5230232665878404, 0.5467145114111778, null, 0.5230232665878404, 0.7974008759015665, null, 0.5230232665878404, 0.3473443627462505, null, 0.5230232665878404, 0.80129889598982, null, 0.5364539776964787, 0.2205595953266284, null, 0.5364539776964787, 0.26808042673921223, null, 0.5364539776964787, 0.5467145114111778, null, 0.5364539776964787, 0.3290079309350088, null, 0.5364539776964787, 0.7974008759015665, null, 0.5364539776964787, 0.80129889598982, null, 1.0, 0.41186983516815334, null, 1.0, 0.9196732654298817, null, 1.0, 0.9240591530786384, null, 1.0, 0.5835924420624169, null, 1.0, 0.4526939577202225, null, 1.0, 0.3290079309350088, null, 1.0, 0.80129889598982, null, 0.608905898657026, 0.41186983516815334, null, 0.608905898657026, 0.2205595953266284, null, 0.608905898657026, 0.9196732654298817, null, 0.608905898657026, 0.9240591530786384, null, 0.608905898657026, 0.40611815720164385, null, 0.608905898657026, 0.5835924420624169, null, 0.608905898657026, 0.26808042673921223, null, 0.608905898657026, 0.6425545033947377, null, 0.608905898657026, 0.3473443627462505, null, 0.4550479772583669, 0.9196732654298817, null, 0.4550479772583669, 0.9240591530786384, null, 0.4550479772583669, 0.26808042673921223, null, 0.4550479772583669, 0.4526939577202225, null, 0.4550479772583669, 0.6425545033947377, null, 0.4550479772583669, 0.0, null, 0.4550479772583669, 0.6519657060978772, null, 0.4550479772583669, 0.3473443627462505, null, 0.4550479772583669, 0.80129889598982, null, 0.41186983516815334, 0.2205595953266284, null, 0.41186983516815334, 0.9196732654298817, null, 0.41186983516815334, 0.5835924420624169, null, 0.41186983516815334, 0.26808042673921223, null, 0.41186983516815334, 0.0, null, 0.41186983516815334, 0.3473443627462505, null, 0.2205595953266284, 0.40611815720164385, null, 0.2205595953266284, 0.26808042673921223, null, 0.2205595953266284, 0.4526939577202225, null, 0.2205595953266284, 0.6425545033947377, null, 0.2205595953266284, 0.3290079309350088, null, 0.9196732654298817, 0.6425545033947377, null, 0.9196732654298817, 0.5467145114111778, null, 0.9196732654298817, 0.6625339828929624, null, 0.9196732654298817, 0.6519657060978772, null, 0.91967 ...

# %% [markdown]
# Custo de manter uma relação do nó $n$:
#
# $$c_n = \left\{\begin{array}{cl}
# 0             & \textrm{se }d_n = 0\textrm{;} \\
# \frac{1}{d_n} & \textrm{caso contrário,} \\
# \end{array}\right.$$
#
# onde $d_n$ é o grau de $n$.

# %%
def cost(g, n):
    dn = g.degree(n)

    if dn == 0:
        return 0
    return 1 / dn

# %% [markdown]
# Restrição do nó $n$ para *openers* (fórmula de Burt):
#
# $$\sum_{m \in N_n} \left(c_n + \sum_{k \in N_n, k \in N_m} c_n c_k\right)^2\textrm{,}$$
#
# onde $N_n$ é o conjunto de vizinhos de $n$.
#
# Esta fórmula parte da premissa de que o nó não está isolado.
#
# Interpretação informal: o agente busca aumentar suas conexões e prefere conexões indiretas.

# %%
def opener_constraint(g, n):
    constraint = 0

    for m in g.neighbors(n):
        sub_constraint = cost(g, n)

        for k in g.neighbors(n):
            if g.has_edge(k, m):
                sub_constraint += cost(g, n) * cost(g, k)

        constraint += sub_constraint**2

    return constraint

# %% [markdown]
# Restrição do nó $n$ para *closers* (uma fórmula alternativa):
#
# $$\frac{9}{8} - b_n\textrm{,}$$
#
# onde $b_n$ é a fórmula de Burt.
#
# Esta fórmula parte da premissa de que o nó não está isolado.
#
# Interpretação informal: o agente busca diminuir suas conexões e prefere conexões diretas.

# %%
def closer_constraint(g, n):
    constraint = 0

    for m in g.neighbors(n):
        sub_constraint = cost(g, n)

        for k in g.neighbors(n):
            if g.has_edge(k, m):
                sub_constraint += cost(g, n) 

        constraint += sub_constraint

    return constraint

# %% [markdown]
# Restrição geral do nó $n$:
#
# * se o nó estiver isolado, é igual a $2$;
# * caso contrário, depende de qual é o tipo.

# %%
def constraint(g, n):
    if g.degree(n) == 0:
        return 2

    if g.nodes[n]['type'] == OPENER:
        return opener_constraint(g, n)
    return closer_constraint(g, n)

# %% [markdown]
# Inicialização da simulação:

# %%
def initialize(g):
    for n in g.nodes:
        g.nodes[n]['constraint'] = constraint(g, n)

# %% [markdown]
# Passo da simulação:
#
# 1. escolha aleatoriamente um par de nós;
# 2. considere uma *inversão* da situação desse par, ou seja, remover a aresta se ela existir ou adicionar se não existir;
# 3. calcule o *ganho* de cada um desses nós, ou seja, a redução da restrição como consequência dessa inversão;
# 4. no caso particular em que a inversão foi adição, se um dos ganhos for negativo, os dois ganhos são redefinidos como zero *(justificativa no código)*;
# 5. se um dos ganhos foi positivo aceite a inversão e termine o passo, senão volte para (1);
# 6. se todos os pares foram escolhidos e nenhuma inversão foi aceita, termine o passo.

# %%
def invert(g, n, m):
    if g.has_edge(n, m):
        g.remove_edge(n, m)
    else:
        g.add_edge(n, m)
        g.edges[n, m]['color'] = sn.edge_color


def update(g):
    # Para cada par de nós, em ordem aleatória.

    pairs = list(combinations(g.nodes, 2))
    shuffle(pairs)

    for n, m in pairs:
        # Inverte a situação do par.
        invert(g, n, m)

        # Calcula as restrições após inversão.
        constraint_n = constraint(g, n)
        constraint_m = constraint(g, m)

        # Calcula os ganhos após inversão,
        # (lembrando que restrição é ruim)
        gain_n = g.nodes[n]['constraint'] - constraint_n
        gain_m = g.nodes[m]['constraint'] - constraint_m

        # Se a inversão foi adição e um dos nós foi prejudicado,
        # então o ganho é zero porque essa inversão é impossível.
        # (você não pode forçar uma pessoa a manter uma relação)
        if g.has_edge(n, m) and (gain_n < 0 or gain_m < 0):
            gain_n = 0
            gain_m = 0

        # Se algum nó teve um ganho, aceita a inversão e
        # considera o passo da simulação como terminado,
        # devolvendo True para indicar que houve mudança.
        if gain_n > 0 or gain_m > 0:
            g.nodes[n]['constraint'] = constraint_n
            g.nodes[m]['constraint'] = constraint_m
            return True

        # Se nenhum nó teve um ganho, essa inversão não é aceita.
        # Restauramos, portanto, a situação original do par de nós.
        invert(g, n, m)

    # Se passamos por todos os pares e nenhuma inversão foi aceita,
    # considera o passo da simulação como terminado, devolvendo
    # False para indicar que não houve mudança: a rede estabilizou.
    return False

# %% [markdown]
# Simulação com visualização, quando todos os nós buscam reduzir a restrição de Burt:

# %%
def simulate(num_closers):
    g = build_graph()

    set_types(g, num_closers)

    initialize(g)

    while update(g):
        pass

    return g


num_closers = 0

g = simulate(num_closers)

sn.reset_positions(g)

sn.show_graph(g)
# Out:
# <div id="2319d568-3e59-4ed3-a7e9-ce70bbda329b" style="height: 450px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2319d568-3e59-4ed3-a7e9-ce70bbda329b", [{"hoverinfo": "none", "line": {"color": "rgb(191, 191, 191)", "width": 1}, "mode": "lines", "x": [0.38995778794602026, 0.5659965195421025, null, 0.38995778794602026, 0.43856217151516014, null, 0.38995778794602026, 0.3733538959263879, null, 0.38995778794602026, 0.6915673725447498, null, 0.38995778794602026, 0.21684229408200814, null, 0.38995778794602026, 0.43681001275199016, null, 0.38995778794602026, 0.49402939992536227, null, 0.38995778794602026, 0.707494461471159, null, 0.38995778794602026, 0.06353953945803699, null, 0.38995778794602026, 0.7761679360073485, null, 0.38995778794602026, 0.9266197326645803, null, 0.38995778794602026, 0.15269047765862614, null, 0.38995778794602026, 0.7896285186352919, null, 0.15269047765862614, 0.942126059341885, null, 0.15269047765862614, 0.17495019843452678, null, 0.15269047765862614, 0.08607544206975794, null, 0.15269047765862614, 0.6586020644906655, null, 0.15269047765862614, 1.0, null, 0.15269047765862614, 0.2839656063311343, null, 0.15269047765862614, 0.6888968353927571, null, 0.15269047765862614, 0.0, null, 0.15269047765862614, 0.9804417220335098, null, 0.15269047765862614, 0.27702735908530574, null, 0.15269047765862614, 0.8222526440133165, null, 0.06353953945803699, 0.0, null, 0.06353953945803699, 1.0, null, 0.06353953945803699, 0.17495019843452678, null, 0.06353953945803699, 0.8222526440133165, null, 0.06353953945803699, 0.27702735908530574, null, 0.06353953945803699, 0.2839656063311343, null, 0.06353953945803699, 0.942126059341885, null, 0.06353953945803699, 0.6586020644906655, null, 0.06353953945803699, 0.08607544206975794, null, 0.06353953945803699, 0.6888968353927571, null, 0.06353953945803699, 0.9804417220335098, null, 0.942126059341885, 0.6915673725447498, null, 0.942126059341885, 0.5659965195421025, null, 0.942126059341885, 0.43856217151516014, null, 0.942126059341885, 0.7896285186352919, null, 0.942126059341885, 0.3733538959263879, null, 0.942126059341885, 0.707494461471159, null, 0.942126059341885, 0.9266197326645803, null, 0.942126059341885, 0.43681001275199016, null, 0.942126059341885, 0.49402939992536227, null, 0.942126059341885, 0.7761679360073485, null, 0.942126059341885, 0.21684229408200814, null, 0.2839656063311343, 0.9266197326645803, null, 0.2839656063311343, 0.49402939992536227, null, 0.2839656063311343, 0.7761679360073485, null, 0.2839656063311343, 0.7896285186352919, null, 0.2839656063311343, 0.21684229408200814, null, 0.2839656063311343, 0.6915673725447498, null, 0.2839656063311343, 0.3733538959263879, null, 0.2839656063311343, 0.5659965195421025, null, 0.2839656063311343, 0.707494461471159, null, 0.2839656063311343, 0.43856217151516014, null, 0.2839656063311343, 0.43681001275199016, null, 0.8222526440133165, 0.9266197326645803, null, 0.8222526440133165, 0.6915673725447498, null, 0.8222526440133165, 0.21684229408200814, null, 0.8222526440133165, 0.7761679360073485, null, 0.8222526440133165, 0.3733538959263879, null, 0.8222526440133165, 0.5659965195421025, null, 0.8222526440133165, 0.49402939992536227, null, 0.8222526440133165, 0.43856217151516014, null, 0.8222526440133165, 0.707494461471159, null, 0.8222526440133165, 0.43681001275199016, null, 0.8222526440133165, 0.7896285186352919, null, 0.08607544206975794, 0.7896285186352919, null, 0.08607544206975794, 0.43681001275199016, null, 0.08607544206975794, 0.3733538959263879, null, 0.08607544206975794, 0.707494461471159, null, 0.08607544206975794, 0.49402939992536227, null, 0.08607544206975794, 0.43856217151516014, null, 0.08607544206975794, 0.9266197326645803, null, 0.08607544206975794, 0.5659965195421025, null, 0.08607544206975794, 0.6915673725447498, null, 0.08607544206975794, 0.21684229408200814,  ...

# %% [markdown]
# Inversão da visualização:

# %%
def inver_show(g):
    cg = nx.complement(g)

    sn.reset_positions(cg)

    for n in g.nodes:
        g.nodes[n]['pos'] = cg.nodes[n]['pos']

    sn.show_graph(g)


inver_show(g)
# Out:
# <div id="75cf7e07-dd77-4c0d-aa87-045c45fe48f4" style="height: 450px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("75cf7e07-dd77-4c0d-aa87-045c45fe48f4", [{"hoverinfo": "none", "line": {"color": "rgb(191, 191, 191)", "width": 1}, "mode": "lines", "x": [0.9605931617667279, 0.17531208689544117, null, 0.9605931617667279, 0.1359292784894906, null, 0.9605931617667279, 0.15190928091145076, null, 0.9605931617667279, 0.07327884229456479, null, 0.9605931617667279, 0.08081548312576142, null, 0.9605931617667279, 0.23279517888291504, null, 0.9605931617667279, 0.21331026312377302, null, 0.9605931617667279, 0.026301242497614105, null, 0.9605931617667279, 0.0, null, 0.9605931617667279, 0.07547129413098821, null, 0.9605931617667279, 0.020882282835137267, null, 0.9605931617667279, 0.11664730063361807, null, 0.9605931617667279, 0.17671938345183374, null, 0.11664730063361807, 0.7740956513612921, null, 0.11664730063361807, 1.0, null, 0.11664730063361807, 0.8511972507485718, null, 0.11664730063361807, 0.915648921263791, null, 0.11664730063361807, 0.9764014854170074, null, 0.11664730063361807, 0.8170959837050968, null, 0.11664730063361807, 0.9303854818590965, null, 0.11664730063361807, 0.8317465140623744, null, 0.11664730063361807, 0.7849228703459289, null, 0.11664730063361807, 0.8990467047172719, null, 0.11664730063361807, 0.8804488955879856, null, 0.0, 0.8317465140623744, null, 0.0, 0.9764014854170074, null, 0.0, 1.0, null, 0.0, 0.8804488955879856, null, 0.0, 0.8990467047172719, null, 0.0, 0.8170959837050968, null, 0.0, 0.7740956513612921, null, 0.0, 0.915648921263791, null, 0.0, 0.8511972507485718, null, 0.0, 0.9303854818590965, null, 0.0, 0.7849228703459289, null, 0.7740956513612921, 0.07327884229456479, null, 0.7740956513612921, 0.17531208689544117, null, 0.7740956513612921, 0.1359292784894906, null, 0.7740956513612921, 0.17671938345183374, null, 0.7740956513612921, 0.15190928091145076, null, 0.7740956513612921, 0.026301242497614105, null, 0.7740956513612921, 0.020882282835137267, null, 0.7740956513612921, 0.23279517888291504, null, 0.7740956513612921, 0.21331026312377302, null, 0.7740956513612921, 0.07547129413098821, null, 0.7740956513612921, 0.08081548312576142, null, 0.8170959837050968, 0.020882282835137267, null, 0.8170959837050968, 0.21331026312377302, null, 0.8170959837050968, 0.07547129413098821, null, 0.8170959837050968, 0.17671938345183374, null, 0.8170959837050968, 0.08081548312576142, null, 0.8170959837050968, 0.07327884229456479, null, 0.8170959837050968, 0.15190928091145076, null, 0.8170959837050968, 0.17531208689544117, null, 0.8170959837050968, 0.026301242497614105, null, 0.8170959837050968, 0.1359292784894906, null, 0.8170959837050968, 0.23279517888291504, null, 0.8804488955879856, 0.020882282835137267, null, 0.8804488955879856, 0.07327884229456479, null, 0.8804488955879856, 0.08081548312576142, null, 0.8804488955879856, 0.07547129413098821, null, 0.8804488955879856, 0.15190928091145076, null, 0.8804488955879856, 0.17531208689544117, null, 0.8804488955879856, 0.21331026312377302, null, 0.8804488955879856, 0.1359292784894906, null, 0.8804488955879856, 0.026301242497614105, null, 0.8804488955879856, 0.23279517888291504, null, 0.8804488955879856, 0.17671938345183374, null, 0.8511972507485718, 0.17671938345183374, null, 0.8511972507485718, 0.23279517888291504, null, 0.8511972507485718, 0.15190928091145076, null, 0.8511972507485718, 0.026301242497614105, null, 0.8511972507485718, 0.21331026312377302, null, 0.8511972507485718, 0.1359292784894906, null, 0.8511972507485718, 0.020882282835137267, null, 0.8511972507485718, 0.17531208689544117, null, 0.8511972507485718, 0.07327884229456479, null, 0.8511972507485718, 0.08081548312576142, null, 0.8511972507485718, 0.07547129413098821, null, 0.9303854818590965, 0.1359292784894906, null, 0.9303854818590965, 0.151909280911450 ...

# %% [markdown]
# Distribuição de *betweenness*:

# %%
betweenness = nx.betweenness_centrality(g)

df = pd.DataFrame({
    'betweenness': [betweenness[n] for n in g.nodes],
})

df.describe()
# Out:
#        betweenness
# count    25.000000
# mean      0.020870
# std       0.002629
# min       0.018395
# 25%       0.018395
# 50%       0.018395
# 75%       0.023551
# max       0.023551

# %% [markdown]
# Simulação com visualização, quando apenas uma minoria dos nós busca reduzir a restrição de Burt, enquanto todos os outros buscam aumentar:

# %%
num_closers = int(FRAC_CLOSERS * NUM_NODES)

g = simulate(num_closers)

sn.reset_positions(g)

sn.show_graph(g)
# Out:
# <div id="0519f091-6690-4d3f-a806-dd94f01b544b" style="height: 450px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0519f091-6690-4d3f-a806-dd94f01b544b", [{"hoverinfo": "none", "line": {"color": "rgb(191, 191, 191)", "width": 1}, "mode": "lines", "x": [1.0, 0.7642800674495072, null, 1.0, 0.5380668333016694, null, 1.0, 0.7027390593692088, null, 1.0, 0.8778340994640089, null, 1.0, 0.40718526620044554, null, 0.3106477452402086, 0.6382722843881841, null, 0.3106477452402086, 0.7527312936766933, null, 0.3106477452402086, 0.5315012182421917, null, 0.3106477452402086, 0.06218307314572343, null, 0.3106477452402086, 0.40718526620044554, null, 0.3106477452402086, 0.7642800674495072, null, 0.3106477452402086, 0.19092987098987435, null, 0.3106477452402086, 0.6753712189531723, null, 0.3106477452402086, 0.5380668333016694, null, 0.3106477452402086, 0.49139444661761444, null, 0.5380668333016694, 0.9293247861468503, null, 0.5380668333016694, 0.4305015993594546, null, 0.5380668333016694, 0.028915492875012643, null, 0.5380668333016694, 0.3844033939082576, null, 0.5380668333016694, 0.6761300064015978, null, 0.5380668333016694, 0.5261875263128843, null, 0.5380668333016694, 0.0, null, 0.5380668333016694, 0.20196370767515168, null, 0.5380668333016694, 0.47457378214201873, null, 0.19092987098987435, 0.6761300064015978, null, 0.19092987098987435, 0.028915492875012643, null, 0.19092987098987435, 0.7027390593692088, null, 0.19092987098987435, 0.0, null, 0.19092987098987435, 0.4305015993594546, null, 0.19092987098987435, 0.20196370767515168, null, 0.3251478060454417, 0.4305015993594546, null, 0.3251478060454417, 0.028915492875012643, null, 0.3251478060454417, 0.7027390593692088, null, 0.3251478060454417, 0.0, null, 0.3251478060454417, 0.20196370767515168, null, 0.3251478060454417, 0.6761300064015978, null, 0.3251478060454417, 0.3844033939082576, null, 0.47457378214201873, 0.7527312936766933, null, 0.47457378214201873, 0.40718526620044554, null, 0.47457378214201873, 0.06218307314572343, null, 0.47457378214201873, 0.6753712189531723, null, 0.47457378214201873, 0.6382722843881841, null, 0.47457378214201873, 0.5315012182421917, null, 0.47457378214201873, 0.7642800674495072, null, 0.47457378214201873, 0.49139444661761444, null, 0.0, 0.40718526620044554, null, 0.0, 0.06218307314572343, null, 0.0, 0.49139444661761444, null, 0.0, 0.24061381706099966, null, 0.6382722843881841, 0.9293247861468503, null, 0.6382722843881841, 0.24061381706099966, null, 0.6382722843881841, 0.3844033939082576, null, 0.6382722843881841, 0.7027390593692088, null, 0.6382722843881841, 0.6761300064015978, null, 0.6382722843881841, 0.8778340994640089, null, 0.6382722843881841, 0.4305015993594546, null, 0.6382722843881841, 0.5261875263128843, null, 0.3844033939082576, 0.7642800674495072, null, 0.3844033939082576, 0.49139444661761444, null, 0.3844033939082576, 0.7527312936766933, null, 0.3844033939082576, 0.6753712189531723, null, 0.3844033939082576, 0.06218307314572343, null, 0.3844033939082576, 0.40718526620044554, null, 0.5261875263128843, 0.06218307314572343, null, 0.5261875263128843, 0.49139444661761444, null, 0.5261875263128843, 0.7527312936766933, null, 0.5261875263128843, 0.40718526620044554, null, 0.5261875263128843, 0.6753712189531723, null, 0.5261875263128843, 0.7642800674495072, null, 0.6761300064015978, 0.7642800674495072, null, 0.6761300064015978, 0.6753712189531723, null, 0.6761300064015978, 0.40718526620044554, null, 0.6761300064015978, 0.5315012182421917, null, 0.6761300064015978, 0.49139444661761444, null, 0.6761300064015978, 0.7527312936766933, null, 0.5315012182421917, 0.8778340994640089, null, 0.5315012182421917, 0.4305015993594546, null, 0.5315012182421917, 0.24061381706099966, null, 0.5315012182421917, 0.7027390593692088, null, 0.7642800674495072, 0.9293247861468503, null, 0.7642800674495072, 0.240613817 ...

# %% [markdown]
# Distribuição de *betweenness*:

# %%
betweenness = nx.betweenness_centrality(g)

df = pd.DataFrame({
    'betweenness': [betweenness[n] for n in g.nodes],
})

df.describe()
# Out:
#        betweenness
# count    25.000000
# mean      0.030145
# std       0.012927
# min       0.011359
# 25%       0.021019
# 50%       0.030678
# 75%       0.041437
# max       0.051225

# %% [markdown]
# Distribuição de *betweenness* dos *openers*:

# %%
betweenness = nx.betweenness_centrality(g)

df = pd.DataFrame({
    'betweenness': [betweenness[n] for n in g.nodes if g.nodes[n]['type'] == OPENER],
})

df.describe()
# Out:
#        betweenness
# count    15.000000
# mean      0.036612
# std       0.010676
# min       0.015072
# 25%       0.032086
# 50%       0.039156
# 75%       0.041437
# max       0.051225

# %% [markdown]
# Distribuição de *betweenness* dos *closers*:

# %%
betweenness = nx.betweenness_centrality(g)

df = pd.DataFrame({
    'betweenness': [betweenness[n] for n in g.nodes if g.nodes[n]['type'] == CLOSER],
})

df.describe()
# Out:
#        betweenness
# count    10.000000
# mean      0.020445
# std       0.009702
# min       0.011359
# 25%       0.013460
# 50%       0.020646
# 75%       0.021419
# max       0.044702
